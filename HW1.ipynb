# %%
#импорт бибилиотеки
import pandas as pd

# %%
#чтение данных
crime_scene_report = pd.read_csv(
    '/Users/user/Library/Mobile Documents/com~apple~CloudDocs/Documents/HSE/1 семестр/Анализ данных и машинное обучение/ДЗ/Data/crime_scene_report.csv')
crime_scene_report
# Out:
#           date     type                                        description  \
# 0     20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1     20180115   murder                  Life? Dont talk to me about life.
# 2     20180115   murder  Mama, I killed a man, put a gun against his he...
# 3     20180215   murder                         REDACTED REDACTED REDACTED
# 4     20180215   murder  Someone killed the guard! He took an arrow to ...
# ...        ...      ...                                                ...
# 1223  20180430  bribery                                                 \n
# 1224  20180430    fraud                  ‘Why not?’ said the March Hare.\n
# 1225  20180430  assault                                                 \n
# 1226  20180501  assault  be NO mistake about it: it was neither more no...
# 1227  20180115   murder  Security footage shows that there were 2 witne...
#
#               city
# 0              NYC
# 1           Albany
# ...

# %%
drivers_license = pd.read_csv(
    '/Users/user/Library/Mobile Documents/com~apple~CloudDocs/Documents/HSE/1 семестр/Анализ данных и машинное обучение/ДЗ/Data/drivers_license.csv')
drivers_license
# Out:
#            id  age  height eye_color hair_color  gender plate_number  \
# 0      100280   72      57     brown        red    male       P24L4U
# 1      100460   63      72     brown      brown  female       XF02T6
# 2      101029   62      74     green      green  female       VKY5KR
# 3      101198   43      54     amber      brown  female       Y5NZ08
# 4      101255   18      79      blue       grey  female       5162Z1
# ...       ...  ...     ...       ...        ...     ...          ...
# 10002  999923   19      77     amber      black  female       5L0ZI4
# 10003  999940   71      61     green      green    male       1B8QN8
# 10004  999981   67      69     brown       blue  female       1684K3
# 10005  999986   49      58     green       grey    male       F8F64H
# 10006  999993   18      63     black      black  female       6UZO2O
#
#          car_make    car_model
# 0           Acura          MDX
# 1        Cadillac          SRX
# 2           Scion           xB
# ...

# %%
facebook_event_checkin = pd.read_csv(
    '/Users/user/Library/Mobile Documents/com~apple~CloudDocs/Documents/HSE/1 семестр/Анализ данных и машинное обучение/ДЗ/Data/facebook_event_checkin.csv')
facebook_event_checkin
# Out:
#        person_id  event_id                                         event_name  \
# 0          28508      5880    Nudists are people who wear one-button suits.\n
# 1          63713      3865  but that's because it's the best book on anyth...
# 2          63713      3999           If Murphy's Law can go wrong, it will.\n
# 3          63713      6436  Old programmers never die.  They just branch t...
# 4          82998      4470               Help a swallow land at Capistrano.\n
# ...          ...       ...                                                ...
# 20006      99716      1143                               SQL Symphony Concert
# 20007      99716      1143                               SQL Symphony Concert
# 20008      99716      1143                               SQL Symphony Concert
# 20009      67318      4719                             The Funky Grooves Tour
# 20010      67318      1143                               SQL Symphony Concert
#
#            date
# ...

# %%
get_fit_now_check_in = pd.read_csv(
    '/Users/user/Library/Mobile Documents/com~apple~CloudDocs/Documents/HSE/1 семестр/Анализ данных и машинное обучение/ДЗ/Data/get_fit_now_check_in.csv')
get_fit_now_check_in
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 0            NL318       20180212            329             365
# 1            NL318       20170811            469             920
# 2            NL318       20180429            506             554
# 3            NL318       20180128            124             759
# 4            NL318       20171027            418            1019
# ...            ...            ...            ...             ...
# 2698         4KB72       20170422           1016            1114
# 2699         4KB72       20170630            408             885
# 2700         48Z7A       20180109           1600            1730
# 2701         48Z55       20180109           1530            1700
# 2702         90081       20180109           1600            1700
#
# [2703 rows x 4 columns]

# %%
get_fit_now_member = pd.read_csv(
    '/Users/user/Library/Mobile Documents/com~apple~CloudDocs/Documents/HSE/1 семестр/Анализ данных и машинное обучение/ДЗ/Data/get_fit_now_member.csv')
get_fit_now_member
# Out:
#         id  person_id                name  membership_start_date  \
# 0    NL318      65076     Everette Koepke               20170926
# 1    AOE21      39426        Noe Locascio               20171005
# 2    2PN28      63823  Jeromy Heitschmidt               20180215
# 3    0YJ24      80651      Waneta Wellard               20171206
# 4    3A08L      32858        Mei Bianchin               20170401
# ..     ...        ...                 ...                    ...
# 179  2V137      41693      Wendell Dulany               20171219
# 180  4KB72      79110          Emile Hege               20170522
# 181  48Z7A      28819        Joe Germuska               20160305
# 182  48Z55      67318       Jeremy Bowers               20160101
# 183  90081      16371      Annabel Miller               20160208
#
#     membership_status
# 0                gold
# 1             regular
# 2              silver
# 3                gold
# 4              silver
# ..                ...
# ...

# %%
income = pd.read_csv(
    '/Users/user/Library/Mobile Documents/com~apple~CloudDocs/Documents/HSE/1 семестр/Анализ данных и машинное обучение/ДЗ/Data/income.csv')
income
# Out:
#             ssn  annual_income
# 0     100009868          52200
# 1     100169584          64500
# 2     100300433          74400
# 3     100355733          35900
# 4     100366269          73000
# ...         ...            ...
# 7509  999679296          54400
# 7510  999762859          77000
# 7511  999824984          82000
# 7512  999910617          82600
# 7513  999942603          11500
#
# [7514 rows x 2 columns]

# %%
interview = pd.read_csv(
    '/Users/user/Library/Mobile Documents/com~apple~CloudDocs/Documents/HSE/1 семестр/Анализ данных и машинное обучение/ДЗ/Data/interview.csv')
interview
# Out:
#       person_id                                         transcript
# 0         28508                ‘I deny it!’ said the March Hare.\n
# 1         63713                                                 \n
# 2         86208      way, and the whole party swam to the shore.\n
# 3         35267  lessons in here? Why, there’s hardly room for ...
# 4         33856                                                 \n
# ...         ...                                                ...
# 4986      37357  Alice did not wish to offend the Dormouse agai...
# 4987      10206  time,’ she said, ‘than waste it in asking ridd...
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...
# 4990      67318  I was hired by a woman with a lot of money. I ...
#
# [4991 rows x 2 columns]

# %%
person = pd.read_csv(
    '/Users/user/Library/Mobile Documents/com~apple~CloudDocs/Documents/HSE/1 семестр/Анализ данных и машинное обучение/ДЗ/Data/person.csv')
person
# Out:
#           id                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10006  99936          Luba Benser      274427             680
# 10007  99941      Roxana Mckimley      975942            1613
# 10008  99965      Cherie Zeimantz      287627            3661
# 10009  99982          Allen Cruse      251350            3126
# 10010  99990         Vance Hunten      830407            3056
#
#       address_street_name        ssn
# 0            Bankhall Ave  747714076
# 1           Gustavus Blvd  477972044
# 2         Northwestern Dr  828638512
# 3           Wood Glade St  614621061
# ...

# %%
#размеры таблиц (разное кол-во строк везде) 
crime_scene_report.shape
# Out:
# (1228, 4)

# %%
drivers_license.shape
# Out:
# (10007, 9)

# %%
facebook_event_checkin.shape
# Out:
# (20011, 4)

# %%
get_fit_now_check_in.shape
# Out:
# (2703, 4)

# %%
get_fit_now_member.shape
# Out:
# (184, 5)

# %%
income.shape
# Out:
# (7514, 2)

# %%
interview.shape
# Out:
# (4991, 2)

# %%
person.shape
# Out:
# (10011, 6)

# %%
#типы данных в таблицах (int и object во всех) 
crime_scene_report.dtypes
# Out:
# date            int64
# type           object
# description    object
# city           object
# dtype: object

# %%
drivers_license.dtypes
# Out:
# id               int64
# age              int64
# height           int64
# eye_color       object
# hair_color      object
# gender          object
# plate_number    object
# car_make        object
# car_model       object
# dtype: object

# %%
facebook_event_checkin.dtypes
# Out:
# person_id      int64
# event_id       int64
# event_name    object
# date           int64
# dtype: object

# %%
get_fit_now_check_in.dtypes
# Out:
# membership_id     object
# check_in_date      int64
# check_in_time      int64
# check_out_time     int64
# dtype: object

# %%
get_fit_now_member.dtypes
# Out:
# id                       object
# person_id                 int64
# name                     object
# membership_start_date     int64
# membership_status        object
# dtype: object

# %%
income.dtypes
# Out:
# ssn              int64
# annual_income    int64
# dtype: object

# %%
interview.dtypes
# Out:
# person_id      int64
# transcript    object
# dtype: object

# %%
person.dtypes
# Out:
# id                      int64
# name                   object
# license_id              int64
# address_number          int64
# address_street_name    object
# ssn                     int64
# dtype: object

# %%
#фильтрация отчета о месте преступления (оставляем строки, где дата - 15.01.2018, тип преступления - убийство, город - SQL City)
crime_scene_report[
    (crime_scene_report['date'] == 20180115) &
    (crime_scene_report['type'] == 'murder') &
    (crime_scene_report['city'] == 'SQL City')
]
# Out:
#           date    type                                        description  \
# 1227  20180115  murder  Security footage shows that there were 2 witne...
#
#           city
# 1227  SQL City

# %%
#вывод описания найденного преступления
crime_scene_report.loc[1227, ['description']]
# Out:
# description    Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".
# Name: 1227, dtype: object

# %%
#поиск человека с именем Аннабель и адресом Франклин Авеню 
person[
    (person['name'].str.contains('Annabel', case=False, na=False)) &
    (person['address_street_name'] == 'Franklin Ave')
]
# Out:
#         id            name  license_id  address_number address_street_name  \
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            ssn
# 665  318771143

# %%
#переименование названия колонки на person_id
person.rename(columns={'id': 'person_id'}, inplace=True)
person.head()
# Out:
#    person_id                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
#
#   address_street_name        ssn
# 0        Bankhall Ave  747714076
# 1       Gustavus Blvd  477972044
# 2     Northwestern Dr  828638512
# 3       Wood Glade St  614621061
# 4       Daws Hill Way  223877684

# %%
#объединение таблиц людей и их интервью по id
merged_interview = pd.merge(person, interview, on='person_id', how='inner')
merged_interview
# Out:
#       person_id                 name  license_id  address_number  \
# 0         10007  Kourtney Calderwood      861794            2791
# 1         10016          Era Moselle      431897            1987
# 2         10025         Trena Hornby      550890             276
# 3         10027      Antione Godbolt      439509            2431
# 4         10034            Kyra Buen      920494            1873
# ...         ...                  ...         ...             ...
# 4986      99866       Colene Newland      416989            2671
# 4987      99888    Edwardo Dicamillo      185669            3759
# 4988      99934       Cherish Aspell      901599             826
# 4989      99936          Luba Benser      274427             680
# 4990      99965      Cherie Zeimantz      287627            3661
#
#      address_street_name        ssn  \
# 0          Gustavus Blvd  477972044
# 1          Wood Glade St  614621061
# 2          Daws Hill Way  223877684
# ...

# %%
#фильтрация интервью свидетеля 
filtered_interview = merged_interview[
    (merged_interview['name'].str.contains('Annabel', case=False, na=False)) &
    (merged_interview['address_street_name'] == 'Franklin Ave')
]
filtered_interview
# Out:
#      person_id            name  license_id  address_number  \
# 321      16371  Annabel Miller      490173             103
#
#     address_street_name        ssn  \
# 321        Franklin Ave  318771143
#
#                                             transcript
# 321  I saw the murder happen, and I recognized the ...

# %%
filtered_interview.iloc[0, 6]
# Out:
# 'I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.'

# %%
#вывод номеров домов на Northwestern Dr
filtered_address = person[
    (person['address_street_name'] == 'Northwestern Dr')
]
filtered_address
# Out:
#       person_id                  name  license_id  address_number  \
# 2         10010             Muoi Cary      385336             741
# 282       12711        Norman Apolito      667757             599
# 499       14887        Morty Schapiro      118009            4919
# 528       15171          Weldon Penso      336999             311
# 811       17729        Lasonya Wildey      439686            3824
# 904       18376              Josh Shi      653712            1091
# 1021      19420           Cody Schiel      890431            3524
# 1338      22239         Dusty Sigafus      710517            1125
# 1426      23044          Val Portlock      924989            3143
# 1522      23960  Kristopher Lagerberg      658777            1392
# 1686      25615         Olevia Morena      388477             812
# 1812      26758      Angelena Billman      942074             629
# 1981      28360        Rashad Cascone      924517            3212
# ...

# %%
#сортировка номеров домов по убыванию и выбор самого первого
filtered_address.sort_values(by='address_number', ascending=False).iloc[0]
# Out:
# person_id                        14887
# name                    Morty Schapiro
# license_id                      118009
# address_number                    4919
# address_street_name    Northwestern Dr
# ssn                          111564949
# Name: 499, dtype: object

# %%
#поиск интервью со вторым свидетелем
merged_interview[
    (merged_interview['name'] == 'Morty Schapiro')
]
# Out:
#      person_id            name  license_id  address_number  \
# 252      14887  Morty Schapiro      118009            4919
#
#     address_street_name        ssn  \
# 252     Northwestern Dr  111564949
#
#                                             transcript
# 252  I heard a gunshot and then saw a man run out. ...

# %%
merged_interview.iloc[252,6]
# Out:
# 'I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".'

# %%
#поиск владельца автомобиля по номеру 
drivers_license[
    (drivers_license['plate_number'].str.contains('H42W', case=False, na=False))&
    (drivers_license['gender'] == 'male')
]
# Out:
#           id  age  height eye_color hair_color gender plate_number   car_make  \
# 3529  423327   30      70     brown      brown   male       0H42W2  Chevrolet
# 6240  664760   21      71     black      black   male       4H42WR     Nissan
#
#      car_model
# 3529  Spark LS
# 6240    Altima

# %%
#переименование названия колонки id
drivers_license.rename(columns={'id': 'license_id'}, inplace=True)

# %%
merged_drivers = pd.merge(person, drivers_license, on='license_id', how='inner')
merged_drivers[
    merged_drivers['license_id'].isin([423327, 664760])
]
# Out:
#       person_id            name  license_id  address_number  \
# 4660      51739  Tushar Chandra      664760             312
# 6323      67318   Jeremy Bowers      423327             530
#
#         address_street_name        ssn  age  height eye_color hair_color  \
# 4660                 Phi St  137882671   21      71     black      black
# 6323  Washington Pl, Apt 3A  871539279   30      70     brown      brown
#
#      gender plate_number   car_make car_model
# 4660   male       4H42WR     Nissan    Altima
# 6323   male       0H42W2  Chevrolet  Spark LS

# %%
#фильтрация местоположения по Facebook трех людей в день убийства
filtered_posts = facebook_event_checkin[
    (facebook_event_checkin['person_id'].isin([51739, 67318]))&
    (facebook_event_checkin['date']==20180115)
]
filtered_posts
# Out:
#        person_id  event_id              event_name      date
# 20009      67318      4719  The Funky Grooves Tour  20180115

# %%
#проверка наличия местоположения для каждого id
for id in [51739, 67318]:
    posts = filtered_posts[filtered_posts['person_id'] == id]
    if posts.empty:
        print(f"Для ID {id}: нет постов")
    else:
        print(f"Для ID {id}:")
        print(posts)
# Out:
# Для ID 51739: нет постов
# Для ID 67318:
#        person_id  event_id              event_name      date
# 20009      67318      4719  The Funky Grooves Tour  20180115

# %%
#переименование колонок таблицы
get_fit_now_member.rename(columns={'id': 'membership_id'}, inplace=True)

# %%
#объединение таблиц спортзала и их пола   
get_fit_now_members = pd.merge(
    get_fit_now_member,
    get_fit_now_check_in,
    on='membership_id',  
    how='inner'          
)
get_fit_now = pd.merge(
    get_fit_now_members,
    merged_drivers[['person_id', 'gender']],
    on='person_id',  
    how='left'          
)
get_fit_now
# Out:
#      membership_id  person_id             name  membership_start_date  \
# 0            NL318      65076  Everette Koepke               20170926
# 1            NL318      65076  Everette Koepke               20170926
# 2            NL318      65076  Everette Koepke               20170926
# 3            NL318      65076  Everette Koepke               20170926
# 4            NL318      65076  Everette Koepke               20170926
# ...            ...        ...              ...                    ...
# 2698         4KB72      79110       Emile Hege               20170522
# 2699         4KB72      79110       Emile Hege               20170522
# 2700         48Z7A      28819     Joe Germuska               20160305
# 2701         48Z55      67318    Jeremy Bowers               20160101
# 2702         90081      16371   Annabel Miller               20160208
#
#      membership_status  check_in_date  check_in_time  check_out_time  gender
# ...

# %%
#поиск второго свидетеля в базе спортзала
get_fit_now [
    get_fit_now['name'] == 'Annabel Miller'
]
# Out:
#      membership_id  person_id            name  membership_start_date  \
# 2702         90081      16371  Annabel Miller               20160208
#
#      membership_status  check_in_date  check_in_time  check_out_time  gender
# 2702              gold       20180109           1600            1700  female

# %%
#проверка подозреваемых по id 
get_fit_now [
    get_fit_now_members['person_id'].isin([51739, 67318])
]
# Out:
#      membership_id  person_id           name  membership_start_date  \
# 2701         48Z55      67318  Jeremy Bowers               20160101
#
#      membership_status  check_in_date  check_in_time  check_out_time gender
# 2701              gold       20180109           1530            1700   male

# %%
#поиск клиентов спортзала с золотым статусом, которые были 9 января 
get_fit_now[
    (get_fit_now['check_in_date'] == 20180109)&
    (get_fit_now['membership_status'] == 'gold')
]
# Out:
#      membership_id  person_id            name  membership_start_date  \
# 1329         XTE42      55662  Sarita Bartosh               20170524
# 1703         6LSTG      83186   Burton Grippe               20170214
# 2435         GE5Q8      92736   Carmen Dimick               20170618
# 2700         48Z7A      28819    Joe Germuska               20160305
# 2701         48Z55      67318   Jeremy Bowers               20160101
# 2702         90081      16371  Annabel Miller               20160208
#
#      membership_status  check_in_date  check_in_time  check_out_time  gender
# 1329              gold       20180109            486            1124  female
# 1703              gold       20180109            399             515    male
# 2435              gold       20180109            367             959  female
# 2700              gold       20180109           1600            1730     NaN
# 2701              gold       20180109           1530            1700    male
# ...

# %%
#вывод подозреваемых 
get_fit_now[
    (get_fit_now['check_in_date'] == 20180109)&
    (get_fit_now['membership_status'] == 'gold')
].loc[2700:2701]
# Out:
#      membership_id  person_id           name  membership_start_date  \
# 2700         48Z7A      28819   Joe Germuska               20160305
# 2701         48Z55      67318  Jeremy Bowers               20160101
#
#      membership_status  check_in_date  check_in_time  check_out_time gender
# 2700              gold       20180109           1600            1730    NaN
# 2701              gold       20180109           1530            1700   male

# %%
#проверка наличия у Jeremy Bowers алиби по местоположению
facebook_event_checkin[
    (facebook_event_checkin['person_id']==67318)
]
# Out:
#        person_id  event_id              event_name      date
# 20009      67318      4719  The Funky Grooves Tour  20180115
# 20010      67318      1143    SQL Symphony Concert  20171206

# %%
#объединение таблиц с персональной информацией
drivers_info = merged_drivers[['person_id','gender', 'age', 'height', 'eye_color', 'hair_color', 'plate_number', 'car_make', 'car_model']]

person_info = pd.merge(
    person,
    drivers_info,
    on='person_id',  
    how='left'          
)

get_fit_now_members_info = get_fit_now_members[['membership_id', 'person_id', 'membership_start_date',
       'membership_status', 'check_in_date', 'check_in_time', 'check_out_time']]

person_info_full = pd.merge(
    person_info,
    get_fit_now_members_info,
    on='person_id',  
    how='left'          
)

person_info_full.head()
# Out:
#    person_id                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
#
#   address_street_name        ssn  gender   age  height eye_color hair_color  \
# 0        Bankhall Ave  747714076    male  46.0    59.0     black      green
# 1       Gustavus Blvd  477972044  female  54.0    74.0     black      white
# 2     Northwestern Dr  828638512  female  24.0    79.0      blue      green
# 3       Wood Glade St  614621061  female  22.0    75.0     amber        red
# 4       Daws Hill Way  223877684  female  45.0    60.0      blue      black
#
#   plate_number       car_make       car_model membership_id  \
# 0       557472       Chrysler  Town & Country           NaN
# ...

# %%
#изменение типа данных
person_info_full.dtypes
columns_to_convert = [
    'age',
    'height',
    'membership_start_date',
    'check_in_date',
    'check_in_time',
    'check_out_time'
]
person_info_full[columns_to_convert]  = person_info_full[columns_to_convert].astype('Int64')

# %%
#портрет преступника
person_info_full.query("name == 'Jeremy Bowers'")
# Out:
#       person_id           name  license_id  address_number  \
# 7851      67318  Jeremy Bowers      423327             530
#
#         address_street_name        ssn gender  age  height eye_color  \
# 7851  Washington Pl, Apt 3A  871539279   male   30      70     brown
#
#      hair_color plate_number   car_make car_model membership_id  \
# 7851      brown       0H42W2  Chevrolet  Spark LS         48Z55
#
#       membership_start_date membership_status  check_in_date  check_in_time  \
# 7851               20160101              gold       20180109           1530
#
#       check_out_time
# 7851            1700

# %%
#сброс индексов и вывод всех записей из отчета в день преступления
crime_description = crime_scene_report.query('date == 20180115')
murderer_description = crime_description.reset_index(drop=True)
murderer_description
# Out:
#         date     type  \
# 0   20180115  robbery
# 1   20180115   murder
# 2   20180115   murder
# 3   20180115    theft
# 4   20180115    fraud
# 5   20180115  assault
# 6   20180115  assault
# 7   20180115    arson
# 8   20180115  bribery
# 9   20180115    fraud
# 10  20180115    fraud
# 11  20180115   murder
#
#                                                                                                                                                                                   description  \
# 0                                                                                                                                           A Man Dressed as Spider-Man Is on a Robbery Spree
# 1                                                                                                                                                           Life? Dont talk to me about life.
# ...

# %%
#проверка наличия интервью у преступника
interview[
    (interview['person_id'].isin([67318]))
]
# Out:
#       person_id  \
# 4990      67318
#
#                                                                                                                                                                                                                                               transcript
# 4990  I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" (65") or 5'7" (67"). She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017.\n

# %%
#проверка названия цвета волос
drivers_license['hair_color'].unique()
# Out:
# array(['red', 'brown', 'green', 'grey', 'blue', 'white', 'black',
#        'blonde'], dtype=object)

# %%
#поиск владельцев автомобилей по описанию из интервью 
merged_drivers[
    ((merged_drivers['car_make']=='Tesla')&
    (merged_drivers['car_model']=='Model S')&
    (merged_drivers['hair_color']=='red')&
    (merged_drivers['gender']=='female'))
]
# Out:
#       person_id              name  license_id  address_number  \
# 7660      78881          Red Korb      918773             107
# 8972      90700     Regina George      291182             332
# 9980      99716  Miranda Priestly      202298            1883
#
#      address_street_name        ssn  age  height eye_color hair_color  gender  \
# 7660         Camerata Dr  961388910   48      65     black        red  female
# 8972           Maple Ave  337169072   65      66      blue        red  female
# 9980          Golden Ave  987756388   68      66     green        red  female
#
#      plate_number car_make car_model
# 7660       917UU3    Tesla   Model S
# 8972       08CM64    Tesla   Model S
# 9980       500123    Tesla   Model S

# %%
#местоположение подозреваемых в Facebook
merged_posts = pd.merge(facebook_event_checkin, person, on='person_id', how='right')
merged_posts[
    (merged_posts['person_id'].isin([78881, 90700, 99716]))
]
# Out:
#        person_id  event_id            event_name        date  \
# 15311      78881       NaN                   NaN         NaN
# 17959      90700       NaN                   NaN         NaN
# 19966      99716    1143.0  SQL Symphony Concert  20171206.0
# 19967      99716    1143.0  SQL Symphony Concert  20171212.0
# 19968      99716    1143.0  SQL Symphony Concert  20171229.0
#
#                    name  license_id  address_number address_street_name  \
# 15311          Red Korb      918773             107         Camerata Dr
# 17959     Regina George      291182             332           Maple Ave
# 19966  Miranda Priestly      202298            1883          Golden Ave
# 19967  Miranda Priestly      202298            1883          Golden Ave
# 19968  Miranda Priestly      202298            1883          Golden Ave
#
#              ssn
# 15311  961388910
# 17959  337169072
# 19966  987756388
# 19967  987756388
# 19968  987756388

# %%
#объединение таблиц по людям и их доходу, сортировка по убыванию и поиск подозреваемых 
merged_income = pd.merge(income, person, on='ssn', how='right').sort_values(by='annual_income', ascending=False)
merged_income[
    (merged_income['person_id'].isin([78881, 90700, 99716]))
]
# Out:
#             ssn  annual_income  person_id              name  license_id  \
# 9985  987756388       310000.0      99716  Miranda Priestly      202298
# 7664  961388910       278000.0      78881          Red Korb      918773
# 8977  337169072            NaN      90700     Regina George      291182
#
#       address_number address_street_name
# 9985            1883          Golden Ave
# 7664             107         Camerata Dr
# 8977             332           Maple Ave

# %%
#портрет преступника и заказчика 
person_info_full[
    person_info_full['name'].isin(['Jeremy Bowers', 'Miranda Priestly'])]
# Out:
#        person_id              name  license_id  address_number  \
# 7851       67318     Jeremy Bowers      423327             530
# 12504      99716  Miranda Priestly      202298            1883
#
#          address_street_name        ssn  gender  age  height eye_color  \
# 7851   Washington Pl, Apt 3A  871539279    male   30      70     brown
# 12504             Golden Ave  987756388  female   68      66     green
#
#       hair_color plate_number   car_make car_model membership_id  \
# 7851       brown       0H42W2  Chevrolet  Spark LS         48Z55
# 12504        red       500123      Tesla   Model S           NaN
#
#        membership_start_date membership_status  check_in_date  check_in_time  \
# 7851                20160101              gold       20180109           1530
# 12504                   <NA>               NaN           <NA>           <NA>
#
#        check_out_time
# 7851             1700
# 12504            <NA>
